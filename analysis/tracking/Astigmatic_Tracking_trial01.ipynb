# %%
from __future__ import division, unicode_literals, print_function  # for compatibility with Python 2 and 3

import matplotlib as mpl
import matplotlib.pyplot as plt

# change the following to %matplotlib notebook for interactive plotting
# %matplotlib inline

# Optionally, tweak styles.
mpl.rc('figure',  figsize=(10, 5))
mpl.rc('image', cmap='gray')
print("done.")
# Out:
# done.

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series  # for convenience

import pims
import trackpy as tp
print("done.")
# Out:
# done.

# %%
@pims.pipeline
def gray(image):
    return image[:, :, 1]  # Take just the green channel
print("done.")
# Out:
# done.

# %%
foo = tp.masks.binary_mask(55,2)
fooc = tp.masks.cosmask(55)
foot = tp.masks.theta_mask(55)

print("done.")
# Out:
# done.

# %%
plt.imshow(foot)

# %%
# ames = gray(pims.open('Z:\\AdhesionData\\2021.06.30__AstigTracking_feasibility01\\*.png'))
frames = pims.open('Z:\\AdhesionData\\2021.06.30__AstigTracking_feasibility01\\*.png')
print('done.')
# Out:
# done.

# %%
type(frames)
# Out:
# pims.image_sequence.ImageSequence

# %%
gframes = gray(pims.open('Z:\\AdhesionData\\2021.06.30__AstigTracking_feasibility01\\*.png'))

# %%
type(gframes)
# Out:
# slicerator.Pipeline

# %%
len(frames)
# Out:
# 51

# %%
len(gframes)
# Out:
# 51

# %%
plt.imshow(frames[1])

# %%
frames
# Out:
# <Frames>
# Source: Z:\AdhesionData\2021.06.30__AstigTracking_feasibility01\*.png
# Length: 51 frames
# Frame Shape: (1536, 2048)
# Pixel Datatype: uint16

# %%
gframes
# Out:
# (ImageSequence,) processed through proc_func. Original repr:
#     <Frames>
#     Source: Z:\AdhesionData\2021.06.30__AstigTracking_feasibility01\*.png
#     Length: 51 frames
#     Frame Shape: (1536, 2048)
#     Pixel Datatype: uint16

# %%
frames[0].frame_no
# Out:
# 0

# %%
frames[0].metadata
# Out:
# {}

# %%
f = tp.locate(frames[1],137,invert=False,minmass=1000000)
print("Done!")
# Out:
# Done!

# %%
f.head()
# Out:
#               y            x          mass       size       ecc       signal  \
# 4    305.557306   183.225279  2.381688e+06  41.873318  0.307680   722.848772
# 15   651.277867   877.083132  2.529226e+06  42.225006  0.384083  1867.608683
# 29  1095.605934  1544.008212  3.627851e+06  37.854309  0.439027  1346.467919
# 32  1227.506746  1602.472166  2.361574e+06  41.003227  0.177929   778.448139
# 36  1287.754820   188.860876  2.681233e+06  42.096712  0.340313   777.650198
#
#       raw_mass  ep  frame
# 4   63534800.0 NaN      1
# 15  63581600.0 NaN      1
# 29  68982384.0 NaN      1
# 32  65910128.0 NaN      1
# 36  64413840.0 NaN      1

# %%
tp.annotate(f, frames[1])
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots()
ax.hist(f['mass'], bins=20)

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
